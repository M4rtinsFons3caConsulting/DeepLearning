# %% [markdown]
# # Album Resizer
#
# This notebook is used to run album resizing routines to make them suitable for specific models.

# %% [markdown]
# ## Imports
#
# Importing the script.

# %%
import os
from deep.constants import IMAGE_DIR, PROCESSED_DIR
from deep.preprocess import resize_inputs
# Out:
# 2025-05-01 02:30:02.442144: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-01 02:30:02.450694: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-01 02:30:02.511651: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-01 02:30:02.568581: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746063002.615519    8435 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746063002.629116    8435 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746063002.731823    8435 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746063002.731843    8435 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746063002.731845    8435 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746063002.731846    8435 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-01 02:30:02.744203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configuration values
if not os.listdir(PROCESSED_DIR):
    target_dir = IMAGE_DIR
else:
    target_dir = PROCESSED_DIR

model = "efficientnetb4"

# %% [markdown]
# ## Resize the images
#
# Resizing will ensure the images are ready to be flowed into the pipeline.

# %%
resize_inputs.resize_album(model, target_dir)
# Out:
# 2025-05-01 02:30:20.271098: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nottoriousgg/miniconda3/envs/deep/lib/python3.11/site-packages/PIL/Image.py:3442: DecompressionBombWarning: Image size (115600000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
