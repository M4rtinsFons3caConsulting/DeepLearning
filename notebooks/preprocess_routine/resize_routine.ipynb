# %% [markdown]
# # Album Resizer
#
# This notebook is used to run album resizing routines to make them suitable for specific models.

# %% [markdown]
# ## Imports
#
# Importing the script.

# %%
from deep.constants import PROCESSED_DIR
from deep.preprocess import resize_inputs
# Out:
# 2025-04-27 12:53:06.308493: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-27 12:53:06.309138: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-27 12:53:06.312570: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-27 12:53:06.321493: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# Configuration values
target_dir = PROCESSED_DIR
model = "efficientnetb4"

# %% [markdown]
# ## Resize the images
#
# Resizing will ensure the images are ready to be flowed into the pipeline.

# %%
resize_inputs.resize_album(model, target_dir)
# Out:
# 2025-04-27 12:53:09.006407: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/20613892_2925671.jpg
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/22627514_323929.jpg
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/22028344_45510504_noanimalcrop.jpg
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/29910702_47363970_noanimalcrop.jpg
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/30004786_982442.jpg
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/29658989_1065063.jpg
# Resized image saved: /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory/20589356_1286909.jpg
# ...
