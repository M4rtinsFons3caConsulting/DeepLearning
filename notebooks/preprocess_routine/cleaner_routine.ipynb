# %% [markdown]
# # Image Cleaner
#
# This notebook is used to preprocess the album.

# %% [markdown]
# ## Imports
#
# Importing the script.

# %%
from deep.preprocess import image_cleaner

# %% [markdown]
# ## Args
#
# Arguments for cleaner are given as a dictionary, and stored as json in `logging/cleaner_logs`.

# %%
config = {
    "median_blur": True,
    "gaussian_blur": False,
    "bilateral": False,
    "meanshift": True,
    "hist_eq": False,
    "clahe": False,
    "gamma_correction": False,
    "gamma": 1.2,
    "imagenet_norm": True
}

# %% [markdown]
# ## Cleaner Routine
#
# And the cleaner routine is run with the above configurations.

# %%
image_cleaner.clean_directory(config=config)
# Out:
# Starting preprocessing from: /home/nottoriousgg/MsC/DeepLearning/data/raw_image_directory → /home/nottoriousgg/MsC/DeepLearning/data/processed_image_directory
# Processing: 20613892_2925671.jpg
# Saved to: 20613892_2925671.jpg
# Processing: 22627514_323929.jpg
# Saved to: 22627514_323929.jpg
# Processing: 22028344_45510504_noanimalcrop.jpg
# Saved to: 22028344_45510504_noanimalcrop.jpg
# Processing: 29910702_47363970_noanimalcrop.jpg
# Saved to: 29910702_47363970_noanimalcrop.jpg
# Processing: 30004786_982442.jpg
# Saved to: 30004786_982442.jpg
# Processing: 29658989_1065063.jpg
# Saved to: 29658989_1065063.jpg
# Processing: 20589356_1286909.jpg
# Saved to: 20589356_1286909.jpg
# Processing: 14129870_912805.jpg
# Saved to: 14129870_912805.jpg
# Processing: 13988233_795456.jpg
# Saved to: 13988233_795456.jpg
# Processing: 22539009_354871.jpg
# Saved to: 22539009_354871.jpg
# Processing: 29435035_1048218.jpg
# Saved to: 29435035_1048218.jpg
# Processing: 28487355_1050315.jpg
# ...
