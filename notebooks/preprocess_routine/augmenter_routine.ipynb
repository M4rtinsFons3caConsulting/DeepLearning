# %% [markdown]
# # Album Augmenter
#
# This notebook is used to run the album augmentation routines.

# %% [markdown]
# ## Imports
#
# Importing the script.

# %%
import pandas as pd
from deep.constants import METADATA_FILE, METADATA_DIR
from deep.preprocess import album_augmenter
# Out:
# 2025-04-23 19:15:11.663624: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-23 19:15:11.672413: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-23 19:15:11.733806: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-23 19:15:11.793422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745432111.845523    4985 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745432111.859819    4985 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745432111.962432    4985 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745432111.962450    4985 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745432111.962452    4985 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745432111.962453    4985 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-23 19:15:11.974708: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configuration values
label = "family"
min_sample = 150
target_ratio = 2.0
output_name = "family_upsample_map"

# %% [markdown]
# ## Generate or load an Upsample map
#
# Images are mapped to transformations, until a desired number of samples is reached.

# %%
# Read the relevant data, selecting only the columns of interest
df = pd.read_csv(METADATA_FILE)[["rare_species_id", "file_path", "label"]]

# For the binary case we need to concatenate

# df = pd.concat([
#     pd.read_csv(METADATA_FILE)[["rare_species_id", "file_path", "label"]],
#     pd.read_csv(METADATA_DIR / "cropped_labels.csv")[["rare_species_id", "file_path", "label"]]
# ], ignore_index=True)

# %%
# A plan can be generated
plan, _ = album_augmenter.generate_oversample_map(
    df=df,
    label=label,
    target_ratio=target_ratio,
    min_samples=min_sample
)

# or, read from the location
# path = UPSAMPLE_JSONS / "filename" # Edit me.
# plan = path

# %% [markdown]
# ## Apply the map
#
# Applying the map will generate the necessary images.

# %%
album_augmenter.oversample_labels(
    output_name=output_name,
    label=label,
    plan=plan
    )
