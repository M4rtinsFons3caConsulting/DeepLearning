# %% [markdown]
# # Album Augmenter
#
# This notebook is used to run the album augmentation routines.

# %% [markdown]
# ## Imports
#
# Importing the script.

# %%
import pandas as pd
from deep.constants import METADATA_FILE, UPSAMPLE_JSONS
from deep.preprocess import album_augmenter
# Out:
# 2025-04-26 01:22:26.551636: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-26 01:22:26.552349: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-26 01:22:26.555592: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-26 01:22:26.564103: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745626946.581271   10218 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745626946.585992   10218 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745626946.598558   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745626946.598576   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745626946.598579   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745626946.598580   10218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-26 01:22:26.602649: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configuration values
label = "family"
min_sample = 150
target_ratio = 2.0
output_name = "family_upsample_map"

# %% [markdown]
# ## Generate or load an Upsample map
#
# Images are mapped to transformations, until a desired number of samples is reached.

# %%
# Read the relevant data, selecting only the columns of interest
df = pd.read_csv(METADATA_FILE)[["rare_species_id", "file_path", f"{label}"]]

# For the binary case we need to concatenate

# df = pd.concat([
#     pd.read_csv(METADATA_FILE)[["rare_species_id", "file_path", "label"]],
#     pd.read_csv(METADATA_DIR / "cropped_labels.csv")[["rare_species_id", "file_path", "label"]]
# ], ignore_index=True)

# %%
# A plan can be generated
# plan = album_augmenter.generate_oversample_map(
#     df=df,
#     label=label,
#     target_ratio=target_ratio,
#     min_samples=min_sample
# ) 

# or, read from the location
path = UPSAMPLE_JSONS / "oversample_plan_20250426T011306Z.json"
plan = path

# %% [markdown]
# ## Apply the map
#
# Applying the map will generate the necessary images.

# %%
album_augmenter.oversample_labels(
    output_name=output_name,
    label=label,
    plan=plan
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 album_augmenter.oversample_labels(
#       2     output_name=output_name,
#       3     label=label,
#       4     plan=plan
#       5     )
#
# File ~/MsC/DeepLearning/deep/preprocess/album_augmenter.py:230, in oversample_labels(label, output_name, plan)
#     228 try:
#     229     img = load_img(source)
# --> 230     new_img = _apply_transformation(img, entry["transform_key"])
#     231     new_img.save(destination)
#     233     augmented_rows.append({
#     234         "rare_species_id": entry['rare_species_id'],
#     235         "file_path": str(filename)
#     236     })
#
# File ~/MsC/DeepLearning/deep/preprocess/album_augmenter.py:200, in _apply_transformation(img, transformation_key)
#     197 aug_iter = datagen.flow(img_array, batch_size=1)
#     198 aug_img_array = next(aug_iter)[0].astype(np.uint8)
# --> 200 return array_to_img(aug_img_array)
#
# File ~/miniconda3/envs/deep/lib/python3.11/site-packages/keras/src/utils/image_utils.py:89, in array_to_img(x, data_format, scale, dtype)
#      87     x = x.transpose(1, 2, 0)
#      88 if scale:
# ---> 89     x = x - np.min(x)
#      90     x_max = np.max(x)
#      91     if x_max != 0:
#
# File ~/miniconda3/envs/deep/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3042, in min(a, axis, out, keepdims, initial, where)
#    2925 @array_function_dispatch(_min_dispatcher)
#    2926 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2927         where=np._NoValue):
#    2928     """
#    2929     Return the minimum of an array or minimum along an axis.
#    2930
#    (...)   3040     6
#    3041     """
# -> 3042     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3043                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniconda3/envs/deep/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
